# %% [markdown]
# <a href="https://colab.research.google.com/github/captaiold/uniswap-v2-periphery/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !head /content/sample_data/california_housing_test.csv
# Out:
# "longitude","latitude","housing_median_age","total_rooms","total_bedrooms","population","households","median_income","median_house_value"
# -122.050000,37.370000,27.000000,3885.000000,661.000000,1537.000000,606.000000,6.608500,344700.000000
# -118.300000,34.260000,43.000000,1510.000000,310.000000,809.000000,277.000000,3.599000,176500.000000
# -117.810000,33.780000,27.000000,3589.000000,507.000000,1484.000000,495.000000,5.793400,270500.000000
# -118.360000,33.820000,28.000000,67.000000,15.000000,49.000000,11.000000,6.135900,330000.000000
# -119.670000,36.330000,19.000000,1241.000000,244.000000,850.000000,237.000000,2.937500,81700.000000
# -119.560000,36.510000,37.000000,1018.000000,213.000000,663.000000,204.000000,1.663500,67000.000000
# -121.430000,38.630000,43.000000,1009.000000,225.000000,604.000000,218.000000,1.664100,67000.000000
# -120.650000,35.480000,19.000000,2310.000000,471.000000,1341.000000,441.000000,3.225000,166900.000000
# ...

# %%
sales = pd.read_csv(
    '/content/sample_data/california_housing_test.csv',
    parse_dates=['longitude'])

# %%
sales.head()
# Out:
#      longitude  latitude  ...  median_income  median_house_value
# 0  -122.050000     37.37  ...         6.6085            344700.0
# 1  -118.300000     34.26  ...         3.5990            176500.0
# 2  -117.810000     33.78  ...         5.7934            270500.0
# 3  -118.360000     33.82  ...         6.1359            330000.0
# 4  -119.670000     36.33  ...         2.9375             81700.0
#
# [5 rows x 9 columns]

# %%
sales.shape
# Out:
# (3000, 9)

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   object
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(8), object(1)
# memory usage: 211.1+ KB

# %%
sales.describe()
# Out:
#          latitude  housing_median_age  ...  median_income  median_house_value
# count  3000.00000         3000.000000  ...    3000.000000          3000.00000
# mean     35.63539           28.845333  ...       3.807272        205846.27500
# std       2.12967           12.555396  ...       1.854512        113119.68747
# min      32.56000            1.000000  ...       0.499900         22500.00000
# 25%      33.93000           18.000000  ...       2.544000        121200.00000
# 50%      34.27000           29.000000  ...       3.487150        177650.00000
# 75%      37.69000           37.000000  ...       4.656475        263975.00000
# max      41.92000           52.000000  ...      15.000100        500001.00000
#
# [8 rows x 8 columns]

# %%
sales['median_income'].describe()
# Out:
# count    3000.000000
# mean        3.807272
# std         1.854512
# min         0.499900
# 25%         2.544000
# 50%         3.487150
# 75%         4.656475
# max        15.000100
# Name: median_income, dtype: float64

# %%
sales['median_income'].value_counts()
# Out:
# 15.0001    9
# 4.0000     8
# 3.3750     8
# 2.1250     7
# 3.8750     7
#           ..
# 1.8723     1
# 8.3818     1
# 3.2727     1
# 4.7984     1
# 8.2827     1
# Name: median_income, Length: 2578, dtype: int64

# %%
sales['median_house_value'].value_counts()
# Out:
# 500001.0    125
# 137500.0     23
# 162500.0     21
# 225000.0     17
# 350000.0     14
#            ...
# 454400.0      1
# 184000.0      1
# 160100.0      1
# 221600.0      1
# 57600.0       1
# Name: median_house_value, Length: 1784, dtype: int64

# %%
sales['median_house_value'].value_counts().plot(kind='pie', figsize=(6,6))

# %%
corr = sales.corr()

corr
# Out:
#                     latitude  ...  median_house_value
# latitude            1.000000  ...           -0.138428
# housing_median_age -0.025143  ...            0.091409
# total_rooms        -0.039632  ...            0.160427
# total_bedrooms     -0.068245  ...            0.082279
# population         -0.117318  ...           -0.001192
# households         -0.068296  ...            0.100176
# median_income      -0.072363  ...            0.672695
# median_house_value -0.138428  ...            1.000000
#
# [8 rows x 8 columns]

# %%
sales.plot(kind='scatter', x='median_income', y='median_house_value', figsize=(6,6))
